# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import LaunchpadWirebondCoupled
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder

# %%
from qiskit_metal.analyses.quantization import EPRanalysis
design.delete_all_components()

# %%
design.overwrite_enabled = True

xmon_options_1 = dict(chip='main', make_fl=False, cross_gap = '30um', cross_width = '30um', cross_length= '240um', 
    connection_pads=dict(
        #dl1 = dict( connector_location = '0', connector_type = '1'),
        b1 = dict(connector_location = '180', connector_type = '0', claw_length = '175um', claw_width = '7um', claw_gap= '6um', ground_spacing='4um'),
        #r1 = dict(connector_location = '90', connector_type = '0', claw_length = '210um', claw_width = '15um', claw_gap= '6um'), 
    
    ),
)

xmon_options_2 = dict(chip='main', make_fl=False, cross_gap = '30um', cross_width = '25um', cross_length= '220um', 
    connection_pads=dict(
        #dl2 = dict( connector_location = '180', connector_type = '1'),
        b2 = dict(connector_location = '-180', connector_type = '0', claw_length = '180um', claw_width = '7um', claw_gap= '6um', ground_spacing='4um'),
        #r2 = dict(connector_location = '90', connector_type = '0', claw_length = '210um', claw_width = '15um', claw_gap= '6um'), 
    
    ),
)

q1 = TransmonCrossFL(design, 'Q1', options=xmon_options_1)
q2 = TransmonCrossFL(design, 'Q2', options=xmon_options_2)

q_pos_y = '-1.3 mm'

q1.options.pos_x = '-1.3mm'
q1.options.pos_y = q_pos_y

q2.options.pos_x = '1.3mm'
q2.options.pos_y = q_pos_y

coupler_options = Dict(chip='main',pin_inputs=Dict(
                                start_pin=dict(component='Q1', pin='b1'),
                        end_pin=dict(
                                component='Q2', pin='b2')),
                        fillet='80um',
                        total_length = '6.5mm',
                        lead = dict(start_straight = '390um', end_straight = '150um',
                                   ), trace_width = '7um')

bus = RouteMeander(design, 'bus1', options= coupler_options)
# Out:
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %% [markdown]
# # Simulating the Bus frequency

# %%
eig_bus = EPRanalysis(design, "hfss")

eig_bus.sim.setup.max_passes = 20
eig_bus.sim.setup.max_delta_f = 0.05
eig_bus.sim.setup.n_modes = 2

eig_bus.sim.run(name="bus1",
               components=['bus1'],
               open_terminations=[('bus1', 'start'), ('bus1', 'end')])

# %%
# %matplotlib inline
eig_bus.sim.plot_convergences()
eig_bus.sim.convergence_f
eig_bus.sim.plot_fields('main')
eig_bus.sim.save_screenshot()

# %%
eig_bus.get_frequencies()

# %%
eig_bus.sim.setup

# %% [markdown]
# # Simulating Q1+Bus+Q2 to extract the coupling strengths

# %%
#Simulate Q1 + bus coupling strength

eig_q12bus = EPRanalysis(design, "hfss")
hfss1 = eig_q12bus.sim.renderer
eig_q12bus.sim.setup.max_passes = 12
eig_q12bus.sim.setup.max_delta_f = 0.05
eig_q12bus.sim.setup.n_modes = 3
eig_q12bus.sim.setup.vars = Dict(Lj1='10.58 nH', Cj1='0 fF', Lj2='7.58 nH', Cj2='0 fF')

# %%
eig_q12bus.sim.renderer.options['x_buffer_width_mm'] = 0.5
eig_q12bus.sim.renderer.options['y_buffer_width_mm'] = 0.5
eig_q12bus.sim.renderer.options
# Out:
# {'Lj': '10nH',
#  'Cj': 0,
#  '_Rj': 0,
#  'max_mesh_length_jj': '7um',
#  'project_path': None,
#  'project_name': None,
#  'design_name': None,
#  'x_buffer_width_mm': 0.5,
#  'y_buffer_width_mm': 0.5,
#  'wb_threshold': '400um',
#  'wb_offset': '0um',
#  'wb_size': 5,
#  'plot_ansys_fields_options': {'name': 'NAME:Mag_E1',
#   'UserSpecifyName': '0',
#   'UserSpecifyFolder': '0',
#   'QuantityName': 'Mag_E',
#   'PlotFolder': 'E Field',
#   'StreamlinePlot': 'False',
#   'AdjacentSidePlot': 'False',
#   'FullModelPlot': 'False',
#   'IntrinsicVar': "Phase='0deg'",
#   'PlotGeomInfo_0': '1',
#   'PlotGeomInfo_1': 'Surface',
#   'PlotGeomInfo_2': 'FacesList',
#   'PlotGeomInfo_3': '1'}}

# %%
eig_q12bus.sim.run(name="Q1+Bus+Q2",
                 components=['Q1', 'bus1', 'Q2'],
                 open_terminations=[])
# Out:
# INFO 12:42PM [connect_design]: 	Opened active design
# 	Design:    Q1+Bus+Q2_hfss [Solution type: Eigenmode]
# INFO 12:42PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:42PM [analyze]: Analyzing setup Setup
# 12:46PM 50s INFO [get_f_convergence]: Saved convergences to C:\Users\Crow104\Dropbox\nonMark_exp\2D_Designs\hfss_eig_f_convergence.csv

# %%
# %matplotlib inline
eig_q12bus.sim.plot_convergences()

# %%
eig_q12bus.sim.convergence_f

eig_q12bus.sim.plot_fields('main', eigenmode=1)
eig_q12bus.sim.save_screenshot()

hfss1.start()

pinfo1 = hfss1.pinfo

#pinfo1.junctions['jj'] = {'Lj_variable': 'Lj', 'rect': 'JJ_rect_Lj_Q1_rect_jj',
#                             'line': 'JJ_Lj_Q1_rect_jj_',  'Cj_variable': 'Cj'}
#pinfo1.validate_junction_info() # Check that valid names of variables and objects have been supplied
#pinfo1.dissipative['dielectrics_bulk'] = ['main'] # Dissipative elements: specify

import pyEPR as epr

eprd1 = epr.DistributedAnalysis(pinfo1)

ℰ_elec = eprd1.calc_energy_electric()
ℰ_elec_substrate = eprd1.calc_energy_electric(None, 'main')
ℰ_mag = eprd1.calc_energy_magnetic()

print(f"""
ℰ_elec_all       = {ℰ_elec}
ℰ_elec_substrate = {ℰ_elec_substrate}
EPR of substrate = {ℰ_elec_substrate / ℰ_elec * 100 :.1f}%

ℰ_mag    = {ℰ_mag}
""")

pinfo1.junctions

eig_q12bus.sim.clear_fields()

eig_q12bus.setup

eig_q12bus.sim.print_run_args()

del eig_q12bus.setup.junctions['jj']
eig_q12bus.setup.junctions.jj1 = Dict(rect='JJ_rect_Lj_Q1_rect_jj', line='JJ_Lj_Q1_rect_jj_', Lj_variable='Lj1', Cj_variable='Cj1')
eig_q12bus.setup.junctions.jj2 = Dict(rect='JJ_rect_Lj_Q2_rect_jj', line='JJ_Lj_Q2_rect_jj_', Lj_variable='Lj2', Cj_variable='Cj2')

eig_q12bus.setup

eig_q12bus.run_epr()
# Out:
# INFO 12:48PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:48PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 12:48PM [load_ansys_project]: 	Opened Ansys App
# INFO 12:48PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 12:48PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/Crow104/Documents/Ansoft/
# 	Project:   Project56
# INFO 12:48PM [connect_design]: 	Opened active design
# 	Design:    Q1+Bus+Q2_hfss [Solution type: Eigenmode]
# INFO 12:48PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:48PM [connect]: 	Connected to project "Project56" and design "Q1+Bus+Q2_hfss" 😀
# Design "Q1+Bus+Q2_hfss" info:
# 	# eigenmodes    3
# 	# variations    1
#
# ℰ_elec_all       = 4.03112750874492e-24
# ℰ_elec_substrate = 3.7053671436888e-24
# EPR of substrate = 91.9%
#
# ℰ_mag    = 5.3073849676243e-26
#
# This analysis object run with the following kwargs:
# {'name': 'Q1+Bus+Q2', 'components': ['Q1', 'bus1', 'Q2'], 'open_terminations': [], 'port_list': None, 'jj_to_port': None, 'ignored_jjs': None, 'box_plus_buffer': True}
#
# Design "Q1+Bus+Q2_hfss" info:
# 	# eigenmodes    3
# 	# variations    1
# Design "Q1+Bus+Q2_hfss" info:
# 	# eigenmodes    3
# 	# variations    1
#
#         energy_elec_all       = 4.03112750874492e-24
#         energy_elec_substrate = 3.7053671436888e-24
#         EPR of substrate = 91.9%
#
#         energy_mag    = 5.3073849676243e-26
#         energy_mag % of energy_elec_all  = 1.3%
#
#
# Variation 0  [1/1]
#
#   Mode 0 at 4.20 GHz   [1/3]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.7%  2.016e-24 2.654e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 98.55%
# 	jj1             0.931443  (+)        0.0137183
# 		Energy fraction (Lj over Lj&Cj)= 98.96%
# 	jj2             1.5328e-06  (+)        1.61739e-08
# 		(U_tot_cap-U_tot_ind)/mean=3.53%
# Calculating Qdielectric_main for mode 0 (0/2)
# p_dielectric_main_0 = 0.919188771789175
#
#   Mode 1 at 4.49 GHz   [2/3]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.7%  1.652e-24 2.124e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 98.34%
# 	jj1             1.20647e-06  (+)        2.03439e-08
# 		Energy fraction (Lj over Lj&Cj)= 98.81%
# 	jj2              1.30127  (+)        0.0157206
# 		(U_tot_cap-U_tot_ind)/mean=-12.81%
# Calculating Qdielectric_main for mode 1 (1/2)
# p_dielectric_main_1 = 0.918343970880243
#
#   Mode 2 at 7.94 GHz   [3/3]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                 0.0%  6.683e-25 6.681e-25
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_2j   sign s_2j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 95.00%
# 	jj1             0.000109635  (+)        5.76719e-06
# 		Energy fraction (Lj over Lj&Cj)= 96.37%
# 	jj2             0.000224539  (+)        8.46237e-06
# 		(U_tot_cap-U_tot_ind)/mean=-0.01%
# Calculating Qdielectric_main for mode 2 (2/2)
# p_dielectric_main_2 = 0.9186023960808342
# WARNING 12:49PM [__init__]: <p>Error: <class 'IndexError'></p>
# ERROR 12:49PM [_get_participation_normalized]: WARNING: U_tot_cap-U_tot_ind / mean = 25.6% is > 15%.
# Is the simulation converged? Proceed with caution
# ANALYSIS DONE. Data saved to:
#
# C:\data-pyEPR\Project56\Q1+Bus+Q2_hfss\2021-12-15 12-48-41.npz
#
#
# 	 Differences in variations:
#
#
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
# INFO 12:49PM [__del__]: Disconnected from Ansys HFSS
# Starting the diagonalization
# INFO 12:49PM [__del__]: Disconnected from Ansys HFSS
# INFO 12:49PM [__del__]: Disconnected from Ansys HFSS
# Finished the diagonalization
# ERROR 12:49PM [_get_participation_normalized]: WARNING: U_tot_cap-U_tot_ind / mean = 25.6% is > 15%.
# Is the simulation converged? Proceed with caution
# Pm_norm=
# modes
# 0    1.073695
# 1    0.771944
# 2    0.837079
# dtype: float64
#
# Pm_norm idx =
#      jj1    jj2
# 0   True  False
# 1  False   True
# 2  False  False
# *** P (participation matrix, not normlz.)
#         jj1       jj2
# 0  0.918838  0.000002
# 1  0.000001  1.281134
# 2  0.000110  0.000225
#
# *** S (sign-bit matrix)
#    s_jj1  s_jj2
# 0      1      1
# 1      1      1
# 2      1      1
# *** P (participation matrix, normalized.)
#       0.99  1.5e-06
#    1.2e-06     0.99
#    0.00011  0.00022
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        139 0.000685   0.0583
#   0.000685      114   0.0918
#     0.0583   0.0918 2.45e-05
#
# *** Chi matrix ND (MHz)
#        149    0.002   0.0567
#      0.002      121   0.0881
#     0.0567   0.0881 2.21e-05
#
# *** Frequencies O1 PT (MHz)
# 0    4060.030745
# 1    4378.357783
# 2    7935.352358
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    4055.117890
# 1    4375.285408
# 2    7935.352502
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\pymetal\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_Lj'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-5dc888ac6a7d> in <module>
#      43 eig_q12bus.setup
#      44
# ---> 45 eig_q12bus.run_epr()
#
# c:\users\crow104\qiskit-metal\qiskit-metal\qiskit_metal\analyses\quantization\energy_participation_ratio.py in run_epr(self, no_junctions)
#     168             self.run_analysis()
#     169             self.spectrum_analysis(self.setup.cos_trunc, self.setup.fock_trunc)
# --> 170             self.report_hamiltonian(self.setup.sweep_variable)
#     171
#     172     # TODO: all the epr methods should not use the renderer. Now they are forced to because of the
#
# c:\users\crow104\qiskit-metal\qiskit-metal\qiskit_metal\analyses\quantization\energy_participation_ratio.py in report_hamiltonian(self, sweep_variable, numeric)
#     221         Eventually, the analysis code needs to be only here, and the renderer method deprecated.
#     222         """
# --> 223         self.sim.renderer.epr_report_hamiltonian(sweep_variable, numeric)
#     224
#     225     def get_frequencies(self):
#
# c:\users\crow104\qiskit-metal\qiskit-metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py in epr_report_hamiltonian(self, swp_variable, numeric)
#    1638         """
#    1639         self.epr_quantum_analysis.plot_hamiltonian_results(
# -> 1640             swp_variable=swp_variable)
#    1641         self.epr_quantum_analysis.report_results(swp_variable=swp_variable,
#    1642                                                  numeric=numeric)
#
# ~\.conda\envs\pymetal\lib\site-packages\pyEPR\core_quantum_analysis.py in plot_hamiltonian_results(self, swp_variable, variations, fig, x_label)
#     855         ### Axis: Frequencies
#     856         f0 = self.results.get_frequencies_HFSS(
# --> 857             variations=variations, vs=swp_variable).transpose()
#     858         f1 = self.results.get_frequencies_O1(
#     859             variations=variations, vs=swp_variable).transpose()
#
# ~\.conda\envs\pymetal\lib\site-packages\pyEPR\core_quantum_analysis.py in get_frequencies_HFSS(self, variations, vs)
#     202     def get_frequencies_HFSS(self, variations: list = None, vs='variation'):
#     203         '''See help for `vs_variations`'''
# --> 204         return self.vs_variations('f_0', variations=variations, vs=vs, to_dataframe=True)
#     205
#     206     def get_frequencies_O1(self, variations: list = None, vs='variation'):
#
# ~\.conda\envs\pymetal\lib\site-packages\pyEPR\core_quantum_analysis.py in vs_variations(self, quantity, variations, vs, to_dataframe)
#     184                 # convert the key to numeric if possible
#     185                 key_new = ureg.Quantity(
# --> 186                     self[key]['hfss_variables']['_'+vs]).magnitude
#     187                 res[key_new] = self[key][quantity]
#     188
#
# ~\.conda\envs\pymetal\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     822
#     823         elif key_is_scalar:
# --> 824             return self._get_value(key)
#     825
#     826         if is_hashable(key):
#
# ~\.conda\envs\pymetal\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     930
#     931         # Similar to Index.get_value, but we do not fall back to positional
# --> 932         loc = self.index.get_loc(label)
#     933         return self.index._get_values_for_loc(self, loc, label)
#     934
#
# ~\.conda\envs\pymetal\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '_Lj'

# %%
eig_q12bus.sim.setup

# %%
eig_q12bus.sim.plot_fields('main', eigenmode=3)
eig_q12bus.sim.save_screenshot()
# Out:
# INFO 12:50PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# WindowsPath('C:/Users/Crow104/Dropbox/nonMark_exp/2D_Designs/ansys.png')
