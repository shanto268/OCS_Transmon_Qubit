# %% [markdown]
# # OCS Qubit
#
# ## To Do:
#
# 1. Create Metal GUI structure for OCS qubit
# 2. Scattering Simulation of OCS structure
# 3. Calculate $w_{01}, E_j$ and $E_c$ from simulation
# 4. Calculate anharmonicity $\alpha$ from `qiskit-metal/hamiltonian/transmon_analytics.py`
#
# ## To Set Up:
#
# 1. Parameter sweep of OCS qubit to get required $\frac{E_j}{E_c} \approx 20$

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import LaunchpadWirebondCoupled
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
# Out:
# D:\Users\lfl\Anaconda3\envs\qiskit-metal\lib\site-packages\pyproj\__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
def set_physical_parameter(value, units):
    if value == 0:
        return 0
    else:
        return str(value)+units

# %% [markdown]
# # Physical Parameters
#
# ## Qubit Physical Parameters

# %%
cross_gap = 30
cross_width = 30
cross_length = 180
L_j = 10
C_j = 0

# %% [markdown]
# ## Claw Physical Parameters

# %%
claw_length = 150
claw_width = 7
claw_gap = 6

# %%
claw_params = dict(connector_location = '90',
                 claw_length =  set_physical_parameter(claw_length, "um"),
                 claw_width = set_physical_parameter(claw_width, "um"),
                 claw_gap =  set_physical_parameter(claw_gap, "um"),
                 ground_spacing = '10um')

# %% [markdown]
# ## Chip Parameters

# %%
chip_x = 5
chip_y = 5

# %%
design = designs.DesignPlanar({}, True)
design.delete_all_components()

design.chips.main.size['size_x'] = set_physical_parameter(chip_x, "mm")
design.chips.main.size['size_y'] = set_physical_parameter(chip_y, "mm")

# %%
gui = MetalGUI(design)

# %% [markdown]
# # Qubit

# %%
design.overwrite_enabled = True

# %%
TransmonCrossFL.get_template_options(design)
# Out:
# {'pos_x': '0.0um',
#  'pos_y': '0.0um',
#  'orientation': '0.0',
#  'chip': 'main',
#  'layer': '1',
#  'connection_pads': {},
#  '_default_connection_pads': {'connector_type': '0',
#   'claw_length': '30um',
#   'ground_spacing': '5um',
#   'claw_width': '10um',
#   'claw_gap': '6um',
#   'connector_location': '0'},
#  'cross_width': '20um',
#  'cross_length': '200um',
#  'cross_gap': '20um',
#  'make_fl': True,
#  'fl_options': {'t_top': '15um',
#   't_offset': '0um',
#   't_inductive_gap': '3um',
#   't_width': '5um',
#   't_gap': '3um'},
#  'hfss_wire_bonds': False,
#  'q3d_wire_bonds': False,
#  'hfss_inductance': '10nH',
#  'hfss_capacitance': 0,
#  'hfss_resistance': 0,
#  'hfss_mesh_kw_jj': 7e-06,
#  'q3d_inductance': '10nH',
#  'q3d_capacitance': 0,
#  'q3d_resistance': 0,
#  'q3d_mesh_kw_jj': 7e-06,
#  'gds_cell_name': 'my_other_junction'}

# %%
left = True

# %%
transmon_options = dict(
        chip = 'main',
        pos_x = '1mm',
        pos_y = '1mm',
        orientation = 270 if left else 90,
        pin_orientation = -90 if left else 90,
        flux_orientation = -90 if left else 90,
        cross_gap = set_physical_parameter(cross_gap, "um"), 
        cross_width = set_physical_parameter(cross_width, "um"), 
        cross_length = set_physical_parameter(cross_length, "um"), 
        hfss_inductance = set_physical_parameter(L_j, "nH"),
        hfss_capacitance = set_physical_parameter(C_j, "fF"),
        q3d_inductance = set_physical_parameter(L_j, "nH"),
        q3d_capacitance = set_physical_parameter(C_j, "fF"),
        connection_pads=dict(
        claw = claw_params,
        )
)

# %%
q1 = TransmonCrossFL(design, 'Q1', options = transmon_options)

# %%
gui.rebuild()
gui.autoscale()
gui.screenshot()

# %% [markdown]
# # Simulation

# %%
# This class lets us get S Y Z parameters
from qiskit_metal.analyses.simulation import ScatteringImpedanceSim
em1 = ScatteringImpedanceSim(design, "hfss")

# %%
em1.run()
# Out:
# INFO 09:28PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 09:28PM [load_ansys_project]: 	Opened Ansys App
# INFO 09:28PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 09:28PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/lfl/Documents/HFSS/
# 	Project:   Project39
# INFO 09:28PM [connect_design]: 	Opened active design
# 	Design:    test_res2_hfss [Solution type: Eigenmode]
# INFO 09:28PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:28PM [connect]: 	Connected to project "Project39" and design "test_res2_hfss" 😀
#
# INFO 09:28PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37860/63370208.py in <module>
# ----> 1 em1.run()
#
# d:\users\lfl\documents\qiskit-metal\qiskit_metal\analyses\core\simulation.py in run(self, *args, **kwargs)
#     201         preventing method name collision when sim and non-sim QAnalysis classes are inherited.
#     202         """
# --> 203         self.run_sim(*args, **kwargs)
#     204
#     205     @abstractmethod
#
# d:\users\lfl\documents\qiskit-metal\qiskit_metal\analyses\simulation\scattering_impedance.py in run_sim(self, name, components, open_terminations, port_list, jj_to_port, ignored_jjs, box_plus_buffer)
#     184             vars_to_initialize=vars_to_initialize)
#     185
# --> 186         self._analyze()
#     187         return renderer_design_name, self.sim_setup_name
#     188
#
# d:\users\lfl\documents\qiskit-metal\qiskit_metal\analyses\simulation\scattering_impedance.py in _analyze(self)
#      89         output of the analysis and stores it in self.params_z/params_y/params_s.
#      90         """
# ---> 91         self.sim_setup_name, self.sweep_name = self.renderer.initialize_drivenmodal(
#      92             **self.setup)
#      93
#
# d:\users\lfl\documents\qiskit-metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py in initialize_drivenmodal(self, sweep_setup, vars, **kwargs)
#     928         self.set_variables(vars)
#     929         setup = self.new_ansys_setup(**kwargs)  # TODO: activate_ansys_setup?
# --> 930         sweep = self.add_sweep(setup.name, **sweep_setup)
#     931         return setup.name, sweep.name
#     932
#
# d:\users\lfl\documents\qiskit-metal\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py in add_sweep(self, setup_name, start_ghz, stop_ghz, count, step_ghz, name, type, save_fields)
#     874         if self.pinfo:
#     875             setup = self.pinfo.get_setup(setup_name)
# --> 876             return setup.insert_sweep(start_ghz=start_ghz,
#     877                                       stop_ghz=stop_ghz,
#     878                                       count=count,
#
# D:\Users\lfl\Anaconda3\envs\qiskit-metal\lib\site-packages\pyEPR\ansys.py in insert_sweep(self, start_ghz, stop_ghz, count, step_ghz, name, type, save_fields)
#    1079             )
#    1080
# -> 1081         name = increment_name(name, self.get_sweep_names())
#    1082         params = [
#    1083             "NAME:" + name,
#
# D:\Users\lfl\Anaconda3\envs\qiskit-metal\lib\site-packages\pyEPR\ansys.py in get_sweep_names(self)
#    1158
#    1159     def get_sweep_names(self):
# -> 1160         return self._setup_module.GetSweeps(self.name)
#    1161
#    1162     def get_sweep(self, name=None):
#
# D:\Users\lfl\Anaconda3\envs\qiskit-metal\lib\site-packages\win32com\client\dynamic.py in GetSweeps(self, setupNameArg)
#
# D:\Users\lfl\Anaconda3\envs\qiskit-metal\lib\site-packages\win32com\client\dynamic.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     366
#     367     def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
# --> 368         result = self._oleobj_.InvokeTypes(
#     369             *(dispid, LCID, wFlags, retType, argTypes) + args
#     370         )
#
# com_error: (-2147417851, 'The server threw an exception.', None, None)

# %%
hfss = em1.renderer
hfss.activate_ansys_design("test_ocs_qubit", 'drivenmodal')

hfss.clean_active_design()

hfss.max_mesh_length_port = '0.01um'
hfss.max_mesh_length_jj = '0.015um'

hfss.render_design(selection=['Q1'], 
                   open_pins = [], 
                   port_list = [('Q1', 'claw',50)],
                   box_plus_buffer = True)
