# %% [markdown]
# # OCS Qubit
#
# ## To Do:
#
# 1. Create Metal GUI structure for OCS qubit
# 2. Scattering Simulation of OCS structure
# 3. Calculate $w_{01}, E_j$ and $E_c$ from simulation
# 4. Calculate anharmonicity $\alpha$ from `qiskit-metal/hamiltonian/transmon_analytics.py`
#
# ## To Set Up:
#
# 1. Parameter sweep of OCS qubit to get required $\frac{E_j}{E_c} \approx 20$

# %%
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
design = designs.DesignPlanar()
gui = MetalGUI(design)

design._chips['main']['size']['size_x'] = '5mm'
design._chips['main']['size']['size_y'] = '5mm'

design.variables['cpw_width'] = '10 um'
design.variables['cpw_gap'] = '6 um'

# %%
#Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True

########## OCS QUBUIT ########
options_d = dict(
    # Some options we want to modify from the defaults
    cross_width = '30um',
    cross_length = '180um',
    cross_gap = '30um',
    chip='main',
    # Adding 3 connectors 
    connection_pads=dict(
        ground_pin  = dict(connector_location = '0', connector_type = '0', claw_width = '19.1um', claw_length = '35.9um', ground_spacing = '5um')
    )
)

q_d = TransmonCross(design, 'Q1', options = dict(
    pos_x='-1250um', pos_y='-1mm', orientation = '90', **options_d))

######### REBUILD ##########

gui.rebuild()
gui.autoscale()
gui.screenshot()

# %%
# This class lets us get S Y Z parameters
from qiskit_metal.analyses.simulation import ScatteringImpedanceSim
em1 = ScatteringImpedanceSim(design, "hfss")

# %%
em1.run()
# Out:
# INFO 10:17PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 10:17PM [load_ansys_project]: 	Opened Ansys App
# INFO 10:17PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 10:17PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/lfl/Documents/HFSS/
# 	Project:   Project39
# INFO 10:17PM [connect_design]: 	Opened active design
# 	Design:    Sweep_DrivenModal_hfss [Solution type: DrivenModal]
# INFO 10:17PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssDMSetup'>)
# INFO 10:17PM [connect]: 	Connected to project "Project39" and design "Sweep_DrivenModal_hfss" 😀
#
# INFO 10:17PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssDMSetup'>)
# INFO 10:17PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssDMSetup'>)
# INFO 10:17PM [analyze]: Analyzing setup Setup : Sweep

# %%
hfss = em1.renderer

hfss.activate_ansys_design("noteeth_test", 'drivenmodal')

# Render Model
hfss.clean_active_design()

hfss.max_mesh_length_port = '0.01um'
hfss.max_mesh_length_jj = '0.015um'

hfss.render_design(selection=['diss'], 
                   open_pins = [], 
                   port_list = [('diss', 'ground_pin', 50)],
                   box_plus_buffer = True)
# Out:
# 10:18PM 21s WARNING [activate_ansys_design]: The design_name=noteeth_test was not in active project.  Designs in active project are:
# ['test_res_hfss', 'TransmonQubit_2', 'test_res2_hfss', 'Sweep_DrivenModal_hfss'].  A new design will be added to the project.
# INFO 10:18PM [connect_design]: 	Opened active design
# 	Design:    noteeth_test [Solution type: DrivenModal]
# WARNING 10:18PM [connect_setup]: 	No design setup detected.
# WARNING 10:18PM [connect_setup]: 	Creating drivenmodal default setup.
# INFO 10:18PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssDMSetup'>)

# %%
hfss.pinfo

# %%
em1.setup.sweep_setup.start_ghz = 5
em1.setup.sweep_setup.stop_ghz = 10

# Change Simulation Settings
em1.setup.reuse_selected_design = False
em1.setup.reuse_setup = False
em1.setup.max_passes = 12
em1.setup.min_passes = 5
em1.setup.max_delta_s = 0.1
em1.setup.min_converged = 5
em1.setup.pct_refinement = 30
em1.setup.sweep_setup.count = 25000
em1.setup.sweep_setup.type = 'Interpolating'
# example: update multiple settings

em1.setup.vars.Lj = '5.49 nH'
em1.setup.vars.Cj = '4.02 fF'

em1.setup.junctions.jj.rect = 'JJ_rect_Lj_diss_rect_jj'
em1.setup.junctions.jj.line = 'JJ_Lj_diss_rect_jj_'

em1.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': False,
#  'reuse_setup': False,
#  'freq_ghz': 5,
#  'max_delta_s': 0.1,
#  'max_passes': 12,
#  'min_passes': 5,
#  'min_converged': 5,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '5.49 nH', 'Cj': '4.02 fF'},
#  'sweep_setup': {'name': 'Sweep',
#   'start_ghz': 5,
#   'stop_ghz': 10,
#   'count': 25000,
#   'step_ghz': None,
#   'type': 'Interpolating',
#   'save_fields': False},
#  'junctions': {'jj': {'rect': 'JJ_rect_Lj_diss_rect_jj',
#    'line': 'JJ_Lj_diss_rect_jj_'}}}

# %%
em1._analyze()
# Out:
# INFO 10:18PM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssDMSetup'>)
# INFO 10:18PM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssDMSetup'>)
# INFO 10:18PM [analyze]: Analyzing setup Setup1 : Sweep

# %%
dataframe_scattering = em1.get_scattering(['S11'])
dataframe_admittance = em1.get_admittance(['Y11'])

df_s = dataframe_scattering[0]
df_y = dataframe_admittance[0]


def get_real_and_imag(a_ii):
    return a_ii.values.real, a_ii.values.imag

s11real, s11imag = get_real_and_imag(df_s['S11'])
y11real, y11imag = get_real_and_imag(df_y['Y11'])


dataframe_scattering[0]['Real(S11)'] = s11real
dataframe_scattering[0]['Imag(S11)'] = s11imag
dataframe_admittance[0]['Real(Y11)'] = y11real
dataframe_admittance[0]['Imag(Y11)'] = y11imag

# %%
import matplotlib.pyplot as plt

# %%
# Reference to current axis.
magnitude = plt.figure('Real S11, Imag S21')
axis = plt.gca() # Get current axis.
dataframe_scattering[0].plot(kind = 'line', y='Real(S11)', color = 'green', ax = axis)
dataframe_scattering[0].plot(kind = 'line', y='Imag(S11)', color = 'blue', ax = axis)
plt.title(f'S-Parameter Amplitude')
plt.xlabel(f'frequency [GHZ]')
plt.ylabel(f're(S11), im(S11) Amp')
magnitude.show()

# %%
# fit to a lorenzian
